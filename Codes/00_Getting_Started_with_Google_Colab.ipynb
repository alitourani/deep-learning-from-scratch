# %% [markdown]
# <a href="https://colab.research.google.com/github/alitourani/deep-learning-from-scratch/blob/main/Codes/00_Getting_Started_with_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **🚀 Welcome to Google Colab!**
#
# You can find an intro to Google Colab in [this link](https://colab.research.google.com/notebooks/intro.ipynb). Easily create a new Colab Notebook from your Google Drive.
#
#
# Note: You can find the presentation for this code sample [here](https://github.com/alitourani/deep-learning-from-scratch/blob/main/Slides/4-Hardware%20and%20Platforms.pdf) (Session 4 - Hardware and Platform)

# %% [markdown]
# **This is a Text cell**

# %%
# And this is a Code Cell
numberOfParticipants = 25
courseName = 'Deep Learning from Scratch'

print(f'There are {numberOfParticipants} people attending the "{courseName}" course.')
# Out:
# There are 25 people attending the "Deep Learning from Scratch" course.

# %% [markdown]
# **This is a Code Snippet**
#
# Load them from **Insert -> Code Snippets**, or simply **Ctrl+Alt+P**

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# **Let's work with popular Python libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0.0, 5.0, 100) # 100 samples between 0 to 5
y = np.sin(4 * np.pi * x) * np.exp(-x)

plt.plot(x, y, 'k')
plt.title('Chart Title')
plt.text(2, 0.65, r'$\sin(2 \pi t) \exp(-t)$') # Chart's inner text
plt.xlabel('X (something)')
plt.ylabel('Y (something)')

plt.subplots_adjust(left = 0.15) # Tune the subplot layout
plt.show()

# %% [markdown]
# **Mount Google Drive**
#
# Use it to import your datasets, store models, etc.

# %%
from google.colab import drive

drive.mount('/content/gdrive')

# Get Access to the files stored on your Drive
googleDriveDirectory = '/content/drive/My Drive/Some Path/'

print('Downloading dataset items ...')
downloadedFile = googleDriveDirectory + 'fileName.txt'
gdd.download_file_from_google_drive(file_id = 'sampleId', dest_path = downloadedFile)
print('Data is ready to be processed!')

# %% [markdown]
# **A Simpe Neural Network**

# %%
from numpy import loadtxt
# We are going to use Keras lib soon. An amazing library for DL
from keras.models import Sequential
from keras.layers import Dense
from tabulate import tabulate

# Loading data
print('Loading dataset ...\n')
# The dataset is Pima Indians onset of diabetes dataset
datasetUrl = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'
dataset = loadtxt(datasetUrl, delimiter=',')
print(f'This dataset has {len(dataset)} instances, like:')

# Showing database rows
rows = ['Pregnancy', 'Plasma', 'Blood Pressure', 'Skin Fold', 'Insulin', 'BMI', 'Diabetes', 'Age', 'Output']
print(tabulate([dataset[1]], headers=rows))

# Data Splitting
print('Splitting dataset ...')
inputItems = dataset[: , 0:8]
outputItems = dataset[: , 8]
print(f'We have split the dataset into {len(inputItems)} and {len(outputItems)} items')

# Defining the model
print('Defining the model ...')
model = Sequential()
model.add(Dense(12, input_dim = 8, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# Compiling
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Fitting the model
print('Training the model ...')
model.fit(inputItems, outputItems, epochs=150, batch_size=10)

# Evaluating
print('Evaulation:')
_, accuracy = model.evaluate(inputItems, outputItems)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Loading dataset ...
#
# This dataset has 768 instances, like:
#   Pregnancy    Plasma    Blood Pressure    Skin Fold    Insulin    BMI    Diabetes    Age    Output
# -----------  --------  ----------------  -----------  ---------  -----  ----------  -----  --------
#           1        85                66           29          0   26.6       0.351     31         0
# Splitting dataset ...
# We have split the dataset into 768 and 768 items
# Defining the model ...
# Training the model ...
# Epoch 1/150
# 77/77 [==============================] - 1s 1ms/step - loss: 9.5373 - accuracy: 0.6350
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 2.4442 - accuracy: 0.6383
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.8175 - accuracy: 0.5932
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.6630 - accuracy: 0.5726
# Epoch 5/150
# ...

# %% [markdown]
# **Let's check our tools!**

# %%
import numpy
import keras

print(f'Numpy version: {numpy.__version__}')
print(f'Keras version: {keras.__version__}')
# Out:
# Numpy version: 1.19.5
# Keras version: 2.5.0
